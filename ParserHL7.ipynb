# %%
# Function to read in HL7 Text File

# %%
def openFile(file):
    with open (file, "r") as f:
        for i, line in enumerate(f):
            print("Line %s %s"% (i, line))

# %%
# Read in HL7 data as lines and store in object 'hl7a'

# %%
hl7a = openFile("data/hl7oru.txt")
# Out:
# Line 0 MSH|^~\&|LCS|LCA|LIS|TEST9999|199807311532||ORU^R01|3629|P|2.2
#
# Line 1 PID|2|2161348462|20809880170|1614614|20809880170^TESTPAT||19760924|M|||^^^^00000-0000|||||||86427531^^^03|SSN# HERE
#
# Line 2 ORC|NW|8642753100012^LIS|20809880170^LCS||||||19980727000000|||HAVILAND
#
# Line 3 OBR|1|8642753100012^LIS|20809880170^LCS|008342^UPPER RESPIRATORY^CULTURE^L|||19980727175800||||||SS#634748641 CH14885 SRC:THROASRC:PENI|19980727000000||||||20809880170||19980730041800||BN|F
#
# Line 4 OBX|1|ST|008342^UPPER RESPIRATORY CULTURE^L||FINALREPORT|||||N|F||| 19980729160500|BN
#
# Line 5 ORC|NW|8642753100012^LIS|20809880170^LCS||||||19980727000000|||HAVILAND
#
# Line 6 OBR|2|8642753100012^LIS|20809880170^LCS|997602^.^L|||19980727175800||||G|||19980727000000||||||20809880170||19980730041800|||F|997602|||008342
#
# Line 7 OBX|2|CE|997231^RESULT 1^L||M415|||||N|F|||19980729160500|BN
#
# Line 8 NTE|1|L|MORAXELLA (BRANHAMELLA) CATARRHALIS
#
# Line 9 NTE|2|L| HEAVY GROWTH
#
# Line 10 NTE|3|L| BETA LACTAMASE POSITIVE
#
# Line 11 OBX|3|CE|997232^RESULT 2^L||MR105|||||N|F|||19980729160500|BN
#
# Line 12 NTE|1|L|ROUTINE RESPIRATORY FLORA

# %%
# Function to parse HL7 data into fields

# %%
def parseFields(file):
    with open (file, "r") as f:
        for i, line in enumerate(f):
            fieldlist = line.split("|")
            for i, field in enumerate(fieldlist):
                print("%s Field %s: %s"%(fieldlist[0], i, field))

# %%
# Parse HL7 data into titled fields

# %%
parseFields("data/hl7oru.txt")
# Out:
# MSH Field 0: MSH
# MSH Field 1: ^~\&
# MSH Field 2: LCS
# MSH Field 3: LCA
# MSH Field 4: LIS
# MSH Field 5: TEST9999
# MSH Field 6: 199807311532
# MSH Field 7:
# MSH Field 8: ORU^R01
# MSH Field 9: 3629
# MSH Field 10: P
# MSH Field 11: 2.2
#
# PID Field 0: PID
# PID Field 1: 2
# PID Field 2: 2161348462
# PID Field 3: 20809880170
# PID Field 4: 1614614
# PID Field 5: 20809880170^TESTPAT
# PID Field 6:
# PID Field 7: 19760924
# PID Field 8: M
# PID Field 9:
# PID Field 10:
# PID Field 11: ^^^^00000-0000
# PID Field 12:
# PID Field 13:
# PID Field 14:
# PID Field 15:
# PID Field 16:
# PID Field 17:
# PID Field 18: 86427531^^^03
# PID Field 19: SSN# HERE
#
# ORC Field 0: ORC
# ORC Field 1: NW
# ORC Field 2: 8642753100012^LIS
# ORC Field 3: 20809880170^LCS
# ORC Field 4:
# ORC Field 5:
# ORC Field 6:
# ORC Field 7:
# ORC Field 8:
# ORC Field 9: 19980727000000
# ORC Field 10:
# ORC Field 11:
# ORC Field 12: HAVILAND
#
# OBR Field 0: OBR
# OBR Field 1: 1
# OBR Field 2: 8642753100012^LIS
# OBR Field 3: 20809880170^LCS
# OBR Field 4: 008342^UPPER RESPIRATORY^CULTURE^L
# OBR Field 5:
# OBR Field 6:
# OBR Field 7: 19980727175800
# OBR Field 8:
# OBR Field 9:
# OBR Field 10:
# OBR Field 11:
# OBR Field 12:
# OBR Field 13: SS#634748641 CH14885 SRC:THROASRC:PENI
# OBR Field 14: 19980727000000
# OBR Field 15:
# OBR Field 16:
# OBR Field 17:
# OBR Field 18:
# OBR Field 19:
# OBR Field 20: 20809880170
# OBR Field 21:
# OBR Field 22: 19980730041800
# OBR Field 23:
# OBR Field 24: BN
# OBR Field 25: F
#
# OBX Field 0: OBX
# OBX Field 1: 1
# OBX Field 2: ST
# OBX Field 3: 008342^UPPER RESPIRATORY CULTURE^L
# OBX Field 4:
# OBX Field 5: FINALREPORT
# OBX Field 6:
# OBX Field 7:
# OBX Field 8:
# OBX Field 9:
# OBX Field 10: N
# OBX Field 11: F
# OBX Field 12:
# OBX Field 13:
# OBX Field 14:  19980729160500
# OBX Field 15: BN
#
# ORC Field 0: ORC
# ORC Field 1: NW
# ORC Field 2: 8642753100012^LIS
# ORC Field 3: 20809880170^LCS
# ORC Field 4:
# ORC Field 5:
# ORC Field 6:
# ORC Field 7:
# ORC Field 8:
# ORC Field 9: 19980727000000
# ORC Field 10:
# ORC Field 11:
# ORC Field 12: HAVILAND
#
# OBR Field 0: OBR
# OBR Field 1: 2
# OBR Field 2: 8642753100012^LIS
# OBR Field 3: 20809880170^LCS
# OBR Field 4: 997602^.^L
# OBR Field 5:
# OBR Field 6:
# OBR Field 7: 19980727175800
# OBR Field 8:
# OBR Field 9:
# OBR Field 10:
# OBR Field 11: G
# OBR Field 12:
# OBR Field 13:
# OBR Field 14: 19980727000000
# OBR Field 15:
# OBR Field 16:
# OBR Field 17:
# OBR Field 18:
# OBR Field 19:
# OBR Field 20: 20809880170
# OBR Field 21:
# OBR Field 22: 19980730041800
# OBR Field 23:
# OBR Field 24:
# OBR Field 25: F
# OBR Field 26: 997602
# OBR Field 27:
# OBR Field 28:
# OBR Field 29: 008342
#
# OBX Field 0: OBX
# OBX Field 1: 2
# OBX Field 2: CE
# OBX Field 3: 997231^RESULT 1^L
# OBX Field 4:
# OBX Field 5: M415
# OBX Field 6:
# OBX Field 7:
# OBX Field 8:
# OBX Field 9:
# OBX Field 10: N
# OBX Field 11: F
# OBX Field 12:
# OBX Field 13:
# OBX Field 14: 19980729160500
# OBX Field 15: BN
#
# NTE Field 0: NTE
# NTE Field 1: 1
# NTE Field 2: L
# NTE Field 3: MORAXELLA (BRANHAMELLA) CATARRHALIS
#
# NTE Field 0: NTE
# NTE Field 1: 2
# NTE Field 2: L
# NTE Field 3:  HEAVY GROWTH
#
# NTE Field 0: NTE
# NTE Field 1: 3
# NTE Field 2: L
# NTE Field 3:  BETA LACTAMASE POSITIVE
#
# OBX Field 0: OBX
# OBX Field 1: 3
# OBX Field 2: CE
# OBX Field 3: 997232^RESULT 2^L
# OBX Field 4:
# OBX Field 5: MR105
# OBX Field 6:
# OBX Field 7:
# OBX Field 8:
# OBX Field 9:
# OBX Field 10: N
# OBX Field 11: F
# OBX Field 12:
# OBX Field 13:
# OBX Field 14: 19980729160500
# OBX Field 15: BN
#
# NTE Field 0: NTE
# NTE Field 1: 1
# NTE Field 2: L
# NTE Field 3: ROUTINE RESPIRATORY FLORA

# %%
# Function to parse HL7 data into components

# %%
def parseComponents(file):
    with open (file, "r") as f:
        for i, line in enumerate(f):
            fields = line.split("|")
            for i, fields in enumerate(fields):
                compsList = fields.split("^")
                for i, comps in enumerate(compsList):
                    print("%s Component %s: %s"%(compsList[0], i, comps))

# %%
# Parse HL7 data into components

# %%
parseComponents("data/hl7oru.txt")
# Out:
# MSH Component 0: MSH
#  Component 0:
#  Component 1: ~\&
# LCS Component 0: LCS
# LCA Component 0: LCA
# LIS Component 0: LIS
# TEST9999 Component 0: TEST9999
# 199807311532 Component 0: 199807311532
#  Component 0:
# ORU Component 0: ORU
# ORU Component 1: R01
# 3629 Component 0: 3629
# P Component 0: P
# 2.2
#  Component 0: 2.2
#
# PID Component 0: PID
# 2 Component 0: 2
# 2161348462 Component 0: 2161348462
# 20809880170 Component 0: 20809880170
# 1614614 Component 0: 1614614
# 20809880170 Component 0: 20809880170
# 20809880170 Component 1: TESTPAT
#  Component 0:
# 19760924 Component 0: 19760924
# M Component 0: M
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 1:
#  Component 2:
#  Component 3:
#  Component 4: 00000-0000
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# 86427531 Component 0: 86427531
# 86427531 Component 1:
# 86427531 Component 2:
# 86427531 Component 3: 03
# SSN# HERE
#  Component 0: SSN# HERE
#
# ORC Component 0: ORC
# NW Component 0: NW
# 8642753100012 Component 0: 8642753100012
# 8642753100012 Component 1: LIS
# 20809880170 Component 0: 20809880170
# 20809880170 Component 1: LCS
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# 19980727000000 Component 0: 19980727000000
#  Component 0:
#  Component 0:
# HAVILAND
#  Component 0: HAVILAND
#
# OBR Component 0: OBR
# 1 Component 0: 1
# 8642753100012 Component 0: 8642753100012
# 8642753100012 Component 1: LIS
# 20809880170 Component 0: 20809880170
# 20809880170 Component 1: LCS
# 008342 Component 0: 008342
# 008342 Component 1: UPPER RESPIRATORY
# 008342 Component 2: CULTURE
# 008342 Component 3: L
#  Component 0:
#  Component 0:
# 19980727175800 Component 0: 19980727175800
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# SS#634748641 CH14885 SRC:THROASRC:PENI Component 0: SS#634748641 CH14885 SRC:THROASRC:PENI
# 19980727000000 Component 0: 19980727000000
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# 20809880170 Component 0: 20809880170
#  Component 0:
# 19980730041800 Component 0: 19980730041800
#  Component 0:
# BN Component 0: BN
# F
#  Component 0: F
#
# OBX Component 0: OBX
# 1 Component 0: 1
# ST Component 0: ST
# 008342 Component 0: 008342
# 008342 Component 1: UPPER RESPIRATORY CULTURE
# 008342 Component 2: L
#  Component 0:
# FINALREPORT Component 0: FINALREPORT
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# N Component 0: N
# F Component 0: F
#  Component 0:
#  Component 0:
#  19980729160500 Component 0:  19980729160500
# BN
#  Component 0: BN
#
# ORC Component 0: ORC
# NW Component 0: NW
# 8642753100012 Component 0: 8642753100012
# 8642753100012 Component 1: LIS
# 20809880170 Component 0: 20809880170
# 20809880170 Component 1: LCS
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# 19980727000000 Component 0: 19980727000000
#  Component 0:
#  Component 0:
# HAVILAND
#  Component 0: HAVILAND
#
# OBR Component 0: OBR
# 2 Component 0: 2
# 8642753100012 Component 0: 8642753100012
# 8642753100012 Component 1: LIS
# 20809880170 Component 0: 20809880170
# 20809880170 Component 1: LCS
# 997602 Component 0: 997602
# 997602 Component 1: .
# 997602 Component 2: L
#  Component 0:
#  Component 0:
# 19980727175800 Component 0: 19980727175800
#  Component 0:
#  Component 0:
#  Component 0:
# G Component 0: G
#  Component 0:
#  Component 0:
# 19980727000000 Component 0: 19980727000000
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# 20809880170 Component 0: 20809880170
#  Component 0:
# 19980730041800 Component 0: 19980730041800
#  Component 0:
#  Component 0:
# F Component 0: F
# 997602 Component 0: 997602
#  Component 0:
#  Component 0:
# 008342
#  Component 0: 008342
#
# OBX Component 0: OBX
# 2 Component 0: 2
# CE Component 0: CE
# 997231 Component 0: 997231
# 997231 Component 1: RESULT 1
# 997231 Component 2: L
#  Component 0:
# M415 Component 0: M415
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# N Component 0: N
# F Component 0: F
#  Component 0:
#  Component 0:
# 19980729160500 Component 0: 19980729160500
# BN
#  Component 0: BN
#
# NTE Component 0: NTE
# 1 Component 0: 1
# L Component 0: L
# MORAXELLA (BRANHAMELLA) CATARRHALIS
#  Component 0: MORAXELLA (BRANHAMELLA) CATARRHALIS
#
# NTE Component 0: NTE
# 2 Component 0: 2
# L Component 0: L
#  HEAVY GROWTH
#  Component 0:  HEAVY GROWTH
#
# NTE Component 0: NTE
# 3 Component 0: 3
# L Component 0: L
#  BETA LACTAMASE POSITIVE
#  Component 0:  BETA LACTAMASE POSITIVE
#
# OBX Component 0: OBX
# 3 Component 0: 3
# CE Component 0: CE
# 997232 Component 0: 997232
# 997232 Component 1: RESULT 2
# 997232 Component 2: L
#  Component 0:
# MR105 Component 0: MR105
#  Component 0:
#  Component 0:
#  Component 0:
#  Component 0:
# N Component 0: N
# F Component 0: F
#  Component 0:
#  Component 0:
# 19980729160500 Component 0: 19980729160500
# BN
#  Component 0: BN
#
# NTE Component 0: NTE
# 1 Component 0: 1
# L Component 0: L
# ROUTINE RESPIRATORY FLORA
#  Component 0: ROUTINE RESPIRATORY FLORA

# %%
# Function to parse HL7 data into subcomponents

# %%
# def parseSubComponents(file):
#    with open (file, "r") as f:
#        for i, line in enumerate(f):
#            fields = line.split("|")
#            for i, fields in enumerate(fields):
#                comps = fields.split("^")
#                for i, comps in enumerate(comps):
#                    subComps = fields.split("^~")
#                    for i, subComps in enumerate(subComps):
#                        print("Sub-Component {}: {}".format(i, subComps))


def parseSubcomponents (file):
    with open(file, 'r') as f:
        for c, line in enumerate (f):
            print ("Segment {}:".format(c))
            for c, fld in enumerate (line.split('|')):
                print ("     Field {}:".format(c))
                if (fld == "^~\&"):
                    print("          SubComponent{}: {}".format(0, fld))
                else:
                    for c, comp in enumerate (fld.split('^')):
                        print("          Component{}:".format(c))
                        for c, subcomp in enumerate (comp.split('~')):
                            print("               SubComponent{}: {}".format(c, subcomp))

# %%
# Parse HL7 data into subcomponents

# %%
 parseSubcomponents("data/hl7oru.txt")
# Out:
# Segment 0:
#      Field 0:
#           Component0:
#                SubComponent0: MSH
#      Field 1:
#           SubComponent0: ^~\&
#      Field 2:
#           Component0:
#                SubComponent0: LCS
#      Field 3:
#           Component0:
#                SubComponent0: LCA
#      Field 4:
#           Component0:
#                SubComponent0: LIS
#      Field 5:
#           Component0:
#                SubComponent0: TEST9999
#      Field 6:
#           Component0:
#                SubComponent0: 199807311532
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0: ORU
#           Component1:
#                SubComponent0: R01
#      Field 9:
#           Component0:
#                SubComponent0: 3629
#      Field 10:
#           Component0:
#                SubComponent0: P
#      Field 11:
#           Component0:
#                SubComponent0: 2.2
#
# Segment 1:
#      Field 0:
#           Component0:
#                SubComponent0: PID
#      Field 1:
#           Component0:
#                SubComponent0: 2
#      Field 2:
#           Component0:
#                SubComponent0: 2161348462
#      Field 3:
#           Component0:
#                SubComponent0: 20809880170
#      Field 4:
#           Component0:
#                SubComponent0: 1614614
#      Field 5:
#           Component0:
#                SubComponent0: 20809880170
#           Component1:
#                SubComponent0: TESTPAT
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0: 19760924
#      Field 8:
#           Component0:
#                SubComponent0: M
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0:
#      Field 11:
#           Component0:
#                SubComponent0:
#           Component1:
#                SubComponent0:
#           Component2:
#                SubComponent0:
#           Component3:
#                SubComponent0:
#           Component4:
#                SubComponent0: 00000-0000
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0:
#      Field 14:
#           Component0:
#                SubComponent0:
#      Field 15:
#           Component0:
#                SubComponent0:
#      Field 16:
#           Component0:
#                SubComponent0:
#      Field 17:
#           Component0:
#                SubComponent0:
#      Field 18:
#           Component0:
#                SubComponent0: 86427531
#           Component1:
#                SubComponent0:
#           Component2:
#                SubComponent0:
#           Component3:
#                SubComponent0: 03
#      Field 19:
#           Component0:
#                SubComponent0: SSN# HERE
#
# Segment 2:
#      Field 0:
#           Component0:
#                SubComponent0: ORC
#      Field 1:
#           Component0:
#                SubComponent0: NW
#      Field 2:
#           Component0:
#                SubComponent0: 8642753100012
#           Component1:
#                SubComponent0: LIS
#      Field 3:
#           Component0:
#                SubComponent0: 20809880170
#           Component1:
#                SubComponent0: LCS
#      Field 4:
#           Component0:
#                SubComponent0:
#      Field 5:
#           Component0:
#                SubComponent0:
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0: 19980727000000
#      Field 10:
#           Component0:
#                SubComponent0:
#      Field 11:
#           Component0:
#                SubComponent0:
#      Field 12:
#           Component0:
#                SubComponent0: HAVILAND
#
# Segment 3:
#      Field 0:
#           Component0:
#                SubComponent0: OBR
#      Field 1:
#           Component0:
#                SubComponent0: 1
#      Field 2:
#           Component0:
#                SubComponent0: 8642753100012
#           Component1:
#                SubComponent0: LIS
#      Field 3:
#           Component0:
#                SubComponent0: 20809880170
#           Component1:
#                SubComponent0: LCS
#      Field 4:
#           Component0:
#                SubComponent0: 008342
#           Component1:
#                SubComponent0: UPPER RESPIRATORY
#           Component2:
#                SubComponent0: CULTURE
#           Component3:
#                SubComponent0: L
#      Field 5:
#           Component0:
#                SubComponent0:
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0: 19980727175800
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0:
#      Field 11:
#           Component0:
#                SubComponent0:
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0: SS#634748641 CH14885 SRC:THROASRC:PENI
#      Field 14:
#           Component0:
#                SubComponent0: 19980727000000
#      Field 15:
#           Component0:
#                SubComponent0:
#      Field 16:
#           Component0:
#                SubComponent0:
#      Field 17:
#           Component0:
#                SubComponent0:
#      Field 18:
#           Component0:
#                SubComponent0:
#      Field 19:
#           Component0:
#                SubComponent0:
#      Field 20:
#           Component0:
#                SubComponent0: 20809880170
#      Field 21:
#           Component0:
#                SubComponent0:
#      Field 22:
#           Component0:
#                SubComponent0: 19980730041800
#      Field 23:
#           Component0:
#                SubComponent0:
#      Field 24:
#           Component0:
#                SubComponent0: BN
#      Field 25:
#           Component0:
#                SubComponent0: F
#
# Segment 4:
#      Field 0:
#           Component0:
#                SubComponent0: OBX
#      Field 1:
#           Component0:
#                SubComponent0: 1
#      Field 2:
#           Component0:
#                SubComponent0: ST
#      Field 3:
#           Component0:
#                SubComponent0: 008342
#           Component1:
#                SubComponent0: UPPER RESPIRATORY CULTURE
#           Component2:
#                SubComponent0: L
#      Field 4:
#           Component0:
#                SubComponent0:
#      Field 5:
#           Component0:
#                SubComponent0: FINALREPORT
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0: N
#      Field 11:
#           Component0:
#                SubComponent0: F
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0:
#      Field 14:
#           Component0:
#                SubComponent0:  19980729160500
#      Field 15:
#           Component0:
#                SubComponent0: BN
#
# Segment 5:
#      Field 0:
#           Component0:
#                SubComponent0: ORC
#      Field 1:
#           Component0:
#                SubComponent0: NW
#      Field 2:
#           Component0:
#                SubComponent0: 8642753100012
#           Component1:
#                SubComponent0: LIS
#      Field 3:
#           Component0:
#                SubComponent0: 20809880170
#           Component1:
#                SubComponent0: LCS
#      Field 4:
#           Component0:
#                SubComponent0:
#      Field 5:
#           Component0:
#                SubComponent0:
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0: 19980727000000
#      Field 10:
#           Component0:
#                SubComponent0:
#      Field 11:
#           Component0:
#                SubComponent0:
#      Field 12:
#           Component0:
#                SubComponent0: HAVILAND
#
# Segment 6:
#      Field 0:
#           Component0:
#                SubComponent0: OBR
#      Field 1:
#           Component0:
#                SubComponent0: 2
#      Field 2:
#           Component0:
#                SubComponent0: 8642753100012
#           Component1:
#                SubComponent0: LIS
#      Field 3:
#           Component0:
#                SubComponent0: 20809880170
#           Component1:
#                SubComponent0: LCS
#      Field 4:
#           Component0:
#                SubComponent0: 997602
#           Component1:
#                SubComponent0: .
#           Component2:
#                SubComponent0: L
#      Field 5:
#           Component0:
#                SubComponent0:
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0: 19980727175800
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0:
#      Field 11:
#           Component0:
#                SubComponent0: G
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0:
#      Field 14:
#           Component0:
#                SubComponent0: 19980727000000
#      Field 15:
#           Component0:
#                SubComponent0:
#      Field 16:
#           Component0:
#                SubComponent0:
#      Field 17:
#           Component0:
#                SubComponent0:
#      Field 18:
#           Component0:
#                SubComponent0:
#      Field 19:
#           Component0:
#                SubComponent0:
#      Field 20:
#           Component0:
#                SubComponent0: 20809880170
#      Field 21:
#           Component0:
#                SubComponent0:
#      Field 22:
#           Component0:
#                SubComponent0: 19980730041800
#      Field 23:
#           Component0:
#                SubComponent0:
#      Field 24:
#           Component0:
#                SubComponent0:
#      Field 25:
#           Component0:
#                SubComponent0: F
#      Field 26:
#           Component0:
#                SubComponent0: 997602
#      Field 27:
#           Component0:
#                SubComponent0:
#      Field 28:
#           Component0:
#                SubComponent0:
#      Field 29:
#           Component0:
#                SubComponent0: 008342
#
# Segment 7:
#      Field 0:
#           Component0:
#                SubComponent0: OBX
#      Field 1:
#           Component0:
#                SubComponent0: 2
#      Field 2:
#           Component0:
#                SubComponent0: CE
#      Field 3:
#           Component0:
#                SubComponent0: 997231
#           Component1:
#                SubComponent0: RESULT 1
#           Component2:
#                SubComponent0: L
#      Field 4:
#           Component0:
#                SubComponent0:
#      Field 5:
#           Component0:
#                SubComponent0: M415
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0: N
#      Field 11:
#           Component0:
#                SubComponent0: F
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0:
#      Field 14:
#           Component0:
#                SubComponent0: 19980729160500
#      Field 15:
#           Component0:
#                SubComponent0: BN
#
# Segment 8:
#      Field 0:
#           Component0:
#                SubComponent0: NTE
#      Field 1:
#           Component0:
#                SubComponent0: 1
#      Field 2:
#           Component0:
#                SubComponent0: L
#      Field 3:
#           Component0:
#                SubComponent0: MORAXELLA (BRANHAMELLA) CATARRHALIS
#
# Segment 9:
#      Field 0:
#           Component0:
#                SubComponent0: NTE
#      Field 1:
#           Component0:
#                SubComponent0: 2
#      Field 2:
#           Component0:
#                SubComponent0: L
#      Field 3:
#           Component0:
#                SubComponent0:  HEAVY GROWTH
#
# Segment 10:
#      Field 0:
#           Component0:
#                SubComponent0: NTE
#      Field 1:
#           Component0:
#                SubComponent0: 3
#      Field 2:
#           Component0:
#                SubComponent0: L
#      Field 3:
#           Component0:
#                SubComponent0:  BETA LACTAMASE POSITIVE
#
# Segment 11:
#      Field 0:
#           Component0:
#                SubComponent0: OBX
#      Field 1:
#           Component0:
#                SubComponent0: 3
#      Field 2:
#           Component0:
#                SubComponent0: CE
#      Field 3:
#           Component0:
#                SubComponent0: 997232
#           Component1:
#                SubComponent0: RESULT 2
#           Component2:
#                SubComponent0: L
#      Field 4:
#           Component0:
#                SubComponent0:
#      Field 5:
#           Component0:
#                SubComponent0: MR105
#      Field 6:
#           Component0:
#                SubComponent0:
#      Field 7:
#           Component0:
#                SubComponent0:
#      Field 8:
#           Component0:
#                SubComponent0:
#      Field 9:
#           Component0:
#                SubComponent0:
#      Field 10:
#           Component0:
#                SubComponent0: N
#      Field 11:
#           Component0:
#                SubComponent0: F
#      Field 12:
#           Component0:
#                SubComponent0:
#      Field 13:
#           Component0:
#                SubComponent0:
#      Field 14:
#           Component0:
#                SubComponent0: 19980729160500
#      Field 15:
#           Component0:
#                SubComponent0: BN
#
# Segment 12:
#      Field 0:
#           Component0:
#                SubComponent0: NTE
#      Field 1:
#           Component0:
#                SubComponent0: 1
#      Field 2:
#           Component0:
#                SubComponent0: L
#      Field 3:
#           Component0:
#                SubComponent0: ROUTINE RESPIRATORY FLORA

# %%
def convertToJSON(file):
    with open (file, 'r') as f:
        file = f.read()
        msgList = file.split('\r\n')
        messages = {}
        for cnt0, msg in enumerate(msgList, 1):
            segmentList = msg.split('\n')
            segments = {}
            segmentTracker = {}
            msgK = 'MSG %s' % cnt0
            for cnt1, seg in enumerate(segmentList, start=1):
                fieldsList = seg.split('|')
                fields = {}
                if (seg == ''):
                    continue
                else:
                    for cnt2, fld in enumerate(fieldsList, start=1):
                        flak = 'FLD %s' % cnt2
                        if (fld == ''):
                            continue
                        elif ((fld == '^~\&') or (fld == '^~`&') or (len(fld.split('^'))==1)):
                            fields[flak] = fld
                        else:
                            componentList = fld.split('^')
                            comps = {} 
                            for cnt3, cmp in enumerate(componentList, start=1):
                                subcomponentList = cmp.split('~')
                                subComps = {}
                                compsK = 'CMP %s' % cnt3
                                if (cmp == ''):
                                    continue
                                elif (len(subcomponentList)==1):
                                    comps[compsK] = cmp
                                else:
                                    for cnt4, sc in enumerate(subcomponentList, start=1):
                                        subCompsK = 'SCMP %s' % cnt4
                                        if (sc == ''):
                                            continue
                                        else:
                                            subComps[subCompsK] = sc
                                    comps[compsK] = subComps
                            fields[flak] = comps
                if (fieldsList[0] not in segmentTracker):
                    segmentTracker[fieldsList[0]] = 1
                else:
                    n = segmentTracker[fieldsList[0]] +1
                    segmentTracker[fieldsList[0]] = n
                segK = '%s %s' % (fieldsList[0], segmentTracker[fieldsList[0]])
                segments[segK] = fields
            messages[msgK] = segments
        print(messages)

# %%
convertToJSON("data/hl7oru.txt")
# Out:
# {'MSG 1': {'MSH 1': {'FLD 1': 'MSH', 'FLD 2': '^~\\&', 'FLD 3': 'LCS', 'FLD 4': 'LCA', 'FLD 5': 'LIS', 'FLD 6': 'TEST9999', 'FLD 7': '199807311532', 'FLD 9': {'CMP 1': 'ORU', 'CMP 2': 'R01'}, 'FLD 10': '3629', 'FLD 11': 'P', 'FLD 12': '2.2'}, 'PID 1': {'FLD 1': 'PID', 'FLD 2': '2', 'FLD 3': '2161348462', 'FLD 4': '20809880170', 'FLD 5': '1614614', 'FLD 6': {'CMP 1': '20809880170', 'CMP 2': 'TESTPAT'}, 'FLD 8': '19760924', 'FLD 9': 'M', 'FLD 12': {'CMP 5': '00000-0000'}, 'FLD 19': {'CMP 1': '86427531', 'CMP 4': '03'}, 'FLD 20': 'SSN# HERE'}, 'ORC 1': {'FLD 1': 'ORC', 'FLD 2': 'NW', 'FLD 3': {'CMP 1': '8642753100012', 'CMP 2': 'LIS'}, 'FLD 4': {'CMP 1': '20809880170', 'CMP 2': 'LCS'}, 'FLD 10': '19980727000000', 'FLD 13': 'HAVILAND'}, 'OBR 1': {'FLD 1': 'OBR', 'FLD 2': '1', 'FLD 3': {'CMP 1': '8642753100012', 'CMP 2': 'LIS'}, 'FLD 4': {'CMP 1': '20809880170', 'CMP 2': 'LCS'}, 'FLD 5': {'CMP 1': '008342', 'CMP 2': 'UPPER RESPIRATORY', 'CMP 3': 'CULTURE', 'CMP 4': 'L'}, 'FLD 8': '19980727175800', 'FLD 14': 'SS#634748641 CH14885 SRC:THROASRC:PENI', 'FLD 15': '19980727000000', 'FLD 21': '20809880170', 'FLD 23': '19980730041800', 'FLD 25': 'BN', 'FLD 26': 'F'}, 'OBX 1': {'FLD 1': 'OBX', 'FLD 2': '1', 'FLD 3': 'ST', 'FLD 4': {'CMP 1': '008342', 'CMP 2': 'UPPER RESPIRATORY CULTURE', 'CMP 3': 'L'}, 'FLD 6': 'FINALREPORT', 'FLD 11': 'N', 'FLD 12': 'F', 'FLD 15': ' 19980729160500', 'FLD 16': 'BN'}, 'ORC 2': {'FLD 1': 'ORC', 'FLD 2': 'NW', 'FLD 3': {'CMP 1': '8642753100012', 'CMP 2': 'LIS'}, 'FLD 4': {'CMP 1': '20809880170', 'CMP 2': 'LCS'}, 'FLD 10': '19980727000000', 'FLD 13': 'HAVILAND'}, 'OBR 2': {'FLD 1': 'OBR', 'FLD 2': '2', 'FLD 3': {'CMP 1': '8642753100012', 'CMP 2': 'LIS'}, 'FLD 4': {'CMP 1': '20809880170', 'CMP 2': 'LCS'}, 'FLD 5': {'CMP 1': '997602', 'CMP 2': '.', 'CMP 3': 'L'}, 'FLD 8': '19980727175800', 'FLD 12': 'G', 'FLD 15': '19980727000000', 'FLD 21': '20809880170', 'FLD 23': '19980730041800', 'FLD 26': 'F', 'FLD 27': '997602', 'FLD 30': '008342'}, 'OBX 2': {'FLD 1': 'OBX', 'FLD 2': '2', 'FLD 3': 'CE', 'FLD 4': {'CMP 1': '997231', 'CMP 2': 'RESULT 1', 'CMP 3': 'L'}, 'FLD 6': 'M415', 'FLD 11': 'N', 'FLD 12': 'F', 'FLD 15': '19980729160500', 'FLD 16': 'BN'}, 'NTE 1': {'FLD 1': 'NTE', 'FLD 2': '1', 'FLD 3': 'L', 'FLD 4': 'MORAXELLA (BRANHAMELLA) CATARRHALIS'}, 'NTE 2': {'FLD 1': 'NTE', 'FLD 2': '2', 'FLD 3': 'L', 'FLD 4': ' HEAVY GROWTH'}, 'NTE 3': {'FLD 1': 'NTE', 'FLD 2': '3', 'FLD 3': 'L', 'FLD 4': ' BETA LACTAMASE POSITIVE'}, 'OBX 3': {'FLD 1': 'OBX', 'FLD 2': '3', 'FLD 3': 'CE', 'FLD 4': {'CMP 1': '997232', 'CMP 2': 'RESULT 2', 'CMP 3': 'L'}, 'FLD 6': 'MR105', 'FLD 11': 'N', 'FLD 12': 'F', 'FLD 15': '19980729160500', 'FLD 16': 'BN'}, 'NTE 4': {'FLD 1': 'NTE', 'FLD 2': '1', 'FLD 3': 'L', 'FLD 4': 'ROUTINE RESPIRATORY FLORA'}}}
